# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from datetime import date

#define figure and axes
fig, ax = plt.subplots(dpi=80)

data = {'modelName': {'evaluation_space/combined_annotations/model'}, 'datasetId': {'evaluation_space/combined_annotations/new_img_bucket'}, 'iou': {'0.75'}, 'imageCount': 61, 'GTCount': 94, 'parts': {'Bumper': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 27.0, 'count': 27}, 'T': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 5.0, 'count': 5}, 'F': {'tot_f1': 0.9111111111111111, 'tot_fnr': 0.1, 'tot_fpr': 0.0, 'accuracy': 13.504950495049505, 'count': 15}, 'D': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 15.0, 'count': 15}, 'QP': {'tot_f1': 0.7333333333333333, 'tot_fnr': 0.26666666666666666, 'tot_fpr': 0.0, 'accuracy': 11.0, 'count': 15}, 'B': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 14.0, 'count': 14}}, 'damages': {'S': {'tot_f1': 0.0, 'tot_fnr': 1.0, 'tot_fpr': 0.0, 'accuracy': 0.0, 'count': 3}, 'MD': {'tot_f1': 0.14285714285714285, 'tot_fnr': 0.8571428571428571, 'tot_fpr': 0.0, 'accuracy': 0.14285714285714285, 'count': 7}}, 'view': {'Rear': {'Bumper': {'accuracy': 1.0, 'count': 15}, 'T': {'accuracy': 1.0, 'count': 5}, 'S': {'accuracy': 0, 'count': 0}, 'MD': {'accuracy': 0, 'count': 0}}, 'Right': {'F': {'accuracy': 0.9292786421499292, 'count': 7}, 'D': {'accuracy': 1.0, 'count': 7}, 'QP': {'accuracy': 0.5, 'count': 6}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 1.0, 'count': 1}}, 'Left': {'F': {'accuracy': 0.875, 'count': 8}, 'D': {'accuracy': 1.0, 'count': 8}, 'QP': {'accuracy': 0.8888888888888888, 'count': 9}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 0.0, 'count': 2}}, 'Front': {'Bumper': {'accuracy': 1.0, 'count': 12}, 'B': {'accuracy': 1.0, 'count': 14}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 0.0, 'count': 4}}}}
today = date.today()

#create values for table
table_data=[
    ["Model Name", data['modelName'].pop()],
    ["Dataset ID", data['datasetId'].pop()],
    ["IOU", data['iou'].pop()],
    ["Image Count", data['imageCount']],
    ["GTCount", data['GTCount']],
    ["Date", today]
]

#create table
table = ax.table(cellText=table_data, loc='center', cellLoc='center')

#modify table
table.auto_set_font_size(False)
table.set_fontsize(14)
table.scale(3,4)
ax.set_axis_off()

#display table
plt.savefig('Model_Info.png', dpi=80, bbox_inches='tight')
plt.show()

data = {'modelName': {'evaluation_space/combined_annotations/model'}, 'datasetId': {'evaluation_space/combined_annotations/new_img_bucket'}, 'iou': {'0.75'}, 'imageCount': 61, 'GTCount': 94, 'parts': {'Bumper': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 27.0, 'count': 27}, 'T': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 5.0, 'count': 5}, 'F': {'tot_f1': 0.9111111111111111, 'tot_fnr': 0.1, 'tot_fpr': 0.0, 'accuracy': 13.504950495049505, 'count': 15}, 'D': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 15.0, 'count': 15}, 'QP': {'tot_f1': 0.7333333333333333, 'tot_fnr': 0.26666666666666666, 'tot_fpr': 0.0, 'accuracy': 11.0, 'count': 15}, 'B': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 14.0, 'count': 14}}, 'damages': {'S': {'tot_f1': 0.0, 'tot_fnr': 1.0, 'tot_fpr': 0.0, 'accuracy': 0.0, 'count': 3}, 'MD': {'tot_f1': 0.14285714285714285, 'tot_fnr': 0.8571428571428571, 'tot_fpr': 0.0, 'accuracy': 0.14285714285714285, 'count': 7}}, 'view': {'Rear': {'Bumper': {'accuracy': 1.0, 'count': 15}, 'T': {'accuracy': 1.0, 'count': 5}, 'S': {'accuracy': 0, 'count': 0}, 'MD': {'accuracy': 0, 'count': 0}}, 'Right': {'F': {'accuracy': 0.9292786421499292, 'count': 7}, 'D': {'accuracy': 1.0, 'count': 7}, 'QP': {'accuracy': 0.5, 'count': 6}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 1.0, 'count': 1}}, 'Left': {'F': {'accuracy': 0.875, 'count': 8}, 'D': {'accuracy': 1.0, 'count': 8}, 'QP': {'accuracy': 0.8888888888888888, 'count': 9}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 0.0, 'count': 2}}, 'Front': {'Bumper': {'accuracy': 1.0, 'count': 12}, 'B': {'accuracy': 1.0, 'count': 14}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 0.0, 'count': 4}}}}
table_data = []
fig, ax = plt.subplots(dpi=80)
table_data.append(['Part', 'Detection F1-score', 'Missed Detection Rate', 'False Detection Rate', 'Mask Quality'])
for part, info in data['parts'].items():
    acbycount = info['accuracy']/info['count']*100
    table_data.append([part, '{:.2f}'.format(info['tot_f1']*100), '{:.2f}'.format(info['tot_fnr']*100), '{:.2f}'.format(info['tot_fpr']*100), '{:.2f}'.format(acbycount)])

table = ax.table(cellText=table_data, loc='center', cellLoc='center')

#modify table
table.auto_set_font_size(False)
table.set_fontsize(14)
table.scale(3,4)
ax.set_axis_off()

# display table
plt.savefig('Part_summary.png', dpi=80, bbox_inches='tight')
plt.show()

data = {'modelName': {'evaluation_space/combined_annotations/model'}, 'datasetId': {'evaluation_space/combined_annotations/new_img_bucket'}, 'iou': {'0.75'}, 'imageCount': 61, 'GTCount': 94, 'parts': {'Bumper': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 27.0, 'count': 27}, 'T': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 5.0, 'count': 5}, 'F': {'tot_f1': 0.9111111111111111, 'tot_fnr': 0.1, 'tot_fpr': 0.0, 'accuracy': 13.504950495049505, 'count': 15}, 'D': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 15.0, 'count': 15}, 'QP': {'tot_f1': 0.7333333333333333, 'tot_fnr': 0.26666666666666666, 'tot_fpr': 0.0, 'accuracy': 11.0, 'count': 15}, 'B': {'tot_f1': 1.0, 'tot_fnr': 0.0, 'tot_fpr': 0.0, 'accuracy': 14.0, 'count': 14}}, 'damages': {'S': {'tot_f1': 0.0, 'tot_fnr': 1.0, 'tot_fpr': 0.0, 'accuracy': 0.0, 'count': 3}, 'MD': {'tot_f1': 0.14285714285714285, 'tot_fnr': 0.8571428571428571, 'tot_fpr': 0.0, 'accuracy': 2, 'count': 7}}, 'view': {'Rear': {'Bumper': {'accuracy': 1.0, 'count': 15}, 'T': {'accuracy': 1.0, 'count': 5}, 'S': {'accuracy': 0, 'count': 0}, 'MD': {'accuracy': 0, 'count': 0}}, 'Right': {'F': {'accuracy': 0.9292786421499292, 'count': 7}, 'D': {'accuracy': 1.0, 'count': 7}, 'QP': {'accuracy': 0.5, 'count': 6}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 1.0, 'count': 1}}, 'Left': {'F': {'accuracy': 0.875, 'count': 8}, 'D': {'accuracy': 1.0, 'count': 8}, 'QP': {'accuracy': 0.8888888888888888, 'count': 9}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 0.0, 'count': 2}}, 'Front': {'Bumper': {'accuracy': 1.0, 'count': 12}, 'B': {'accuracy': 1.0, 'count': 14}, 'S': {'accuracy': 0.0, 'count': 1}, 'MD': {'accuracy': 0.0, 'count': 4}}}}
table_data = []
fig, ax = plt.subplots(dpi=80)
table_data.append(['Damages', 'Detection F1-score', 'Missed Detection Rate', 'False Detection Rate', 'Mask Quality'])
for part, info in data['damages'].items():
    acbycount = info['accuracy']/info['count']*100
    table_data.append([part, '{:.2f}'.format(info['tot_f1']*100), '{:.2f}'.format(info['tot_fnr']*100), '{:.2f}'.format(info['tot_fpr']*100), '{:.2f}'.format(acbycount)])

table = ax.table(cellText=table_data, loc='center', cellLoc='center')

#modify table
table.auto_set_font_size(False)
table.set_fontsize(14)
table.scale(3,4)
ax.set_axis_off()

# display table
plt.savefig('Damages_summary.png', dpi=80, bbox_inches='tight')
plt.show()

# %% [markdown]
# #####
